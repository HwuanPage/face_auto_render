# %%
""" F12를 눌러서 Console에다가 붙여넣어서 실행시 런타임 끊김 방지

function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}

setInterval(KeepClicking,60000)

"""
# Out:
# ' F12를 눌러서 Console에다가 붙여넣어서 실행시 런타임 끊김 방지\n\nfunction KeepClicking(){\nconsole.log("Clicking");\ndocument.querySelector("colab-connect-button").click()\n}\n\nsetInterval(KeepClicking,60000)\n\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import os, sys
GDRIVE_HOME = '/content/drive/MyDrive'
WORK_SPACE = 'Colab Notebooks/graduation'
working = os.path.join(GDRIVE_HOME, WORK_SPACE)
sys.path.append(working)

# %%
# !pip install imgui glfw pyspng mrcfile ninja plyfile trimesh onnxruntime onnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 690.6/690.6 kB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 58.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 46.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 14.1 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python dlib pyyaml onnxruntime onnx

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/graduation'
# Out:
# /content/drive/MyDrive/Colab Notebooks/graduation

# %%
# %cd ./3DD_Pano/
# Out:
# /content/drive/MyDrive/Colab Notebooks/graduation/3DD_Pano

# %%
# !sh ./build.sh

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Colab Notebooks/graduation

# %%
PASSWORD = '2903'

# %%
# !pip install colab-ssh --upgrade

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared

# %%
# !chmod  +x ./cloudflared

# %%
launch_ssh_cloudflared(password=PASSWORD)
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...
